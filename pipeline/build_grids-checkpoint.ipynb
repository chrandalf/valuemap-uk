# %%
import os, time, requests
URL = "http://prod.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-complete.txt"
##URL = "https://s3.eu-west-1.amazonaws.com/prod1.publicdata.landregistry.gov.uk/pp-2025.txt"
OUT = "pp-2025.txt"

def download_resume(url, out_path, retries=20, chunk_size=1024*1024):
    s = requests.Session()
    headers = {"User-Agent": "Mozilla/5.0", "Accept-Encoding": "identity"}
    downloaded = os.path.getsize(out_path) if os.path.exists(out_path) else 0

    for attempt in range(1, retries + 1):
        try:
            h = headers.copy()
            if downloaded:
                h["Range"] = f"bytes={downloaded}-"

            with s.get(url, stream=True, headers=h, timeout=(30, 300)) as r:
                if r.status_code == 416:
                    print("Already complete.")
                    return
                r.raise_for_status()

                mode = "ab" if downloaded else "wb"# %% [code] {"execution":{"iopub.status.busy":"2026-02-10T06:13:53.846759Z","iopub.execute_input":"2026-02-10T06:13:53.847496Z","iopub.status.idle":"2026-02-10T06:15:18.464643Z","shell.execute_reply.started":"2026-02-10T06:13:53.847443Z","shell.execute_reply":"2026-02-10T06:15:18.463419Z"},"jupyter":{"outputs_hidden":false}}

                with open(out_path, mode) as f:
                    last = time.time()
                    for chunk in r.iter_content(chunk_size=chunk_size):
                        if not chunk:
                            continue
                        f.write(chunk)
                        downloaded += len(chunk)
                        if time.time() - last > 2:
                            print(f"\rDownloaded {downloaded/1e6:,.1f} MB", end="")
                            last = time.time()

            print(f"\nDone: {out_path}")
            return

        except (requests.Timeout, requests.ConnectionError) as e:
            wait = min(2 ** attempt, 60)
            print(f"\nAttempt {attempt} failed: {e} | retrying in {wait}s (resume at {downloaded/1e6:,.1f} MB)")
            time.sleep(wait)

    raise RuntimeError("Failed after retries")

download_resume(URL, OUT)
# Out:
# Downloaded 5,206.2 MB
# Done: pp-2025.txt

# %%
import os
print(os.getcwd())
print(os.listdir(".")[:50])
# Out:
# C:\Users\chris
# ['.bash_history', '.codex', '.conda', '.condarc', '.continuum', '.copilot', '.dbus-keyrings', '.dotnet', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.matplotlib', '.nuget', '.spyder-py3', '.templateengine', '.vscode', '3D Objects', 'AppData', 'Application Data', 'attempt_btc.csv', 'bin_trendsv4_class.py', 'brickgrid-web', 'BTCUSDT-15m-data.csv', 'BTCUSDT-1h-data.csv', 'chris_test.csv', 'Contacts', 'Cookies', 'csat_interview.xlsx', 'DaVinci Resolve Media', 'deepL-translate', 'Documents', 'Downloads', 'Favorites', 'FETUSDT-1h-data.csv', 'gametest', 'GhostofRockNRoll', 'Jedi', 'Links', 'LINKUSDT-1h-data.csv', 'Local Settings', 'Movies', 'Music', 'My Documents', 'My project', 'NetHood', 'node_modules', 'NTUSER.DAT', 'ntuser.dat.LOG1']

# %%
import pandas as pd
import hashlib

path_scot = "/users/chris/scot_house_sold.csv"  # change if needed
DAILY_THRESHOLD = 50  # you said 50

def parse_scot_date(s: pd.Series) -> pd.Series:
    s = s.astype("string").str.strip()
    dt = pd.to_datetime(s, format="%d-%m-%Y", errors="coerce")
    m = dt.isna()
    if m.any():
        dt[m] = pd.to_datetime(s[m], dayfirst=True, errors="coerce")
    return dt

today = pd.Timestamp.today().normalize()

# Load minimal columns
raw = pd.read_csv(
    path_scot,
    usecols=["Postcode", "Date", "Price", "Link"],
    dtype={"Postcode": "string", "Date": "string", "Price": "string", "Link": "string"},
)

# Clean
raw["postcode"] = raw["Postcode"].str.strip().str.upper()
raw["date"] = parse_scot_date(raw["Date"])
raw = raw[raw["date"].notna() & (raw["date"] <= today)]

price_clean = (
    raw["Price"]
      .str.replace("£", "", regex=False)
      .str.replace(",", "", regex=False)
      .str.strip()
)
raw["price"] = pd.to_numeric(price_clean, errors="coerce")
raw = raw[raw["price"].notna()]

# --- find latest "busy day" ---
daily_counts = raw.groupby(raw["date"].dt.normalize()).size().sort_index()

busy_days = daily_counts[daily_counts >= DAILY_THRESHOLD]
if not busy_days.empty:
    end_date = busy_days.index.max()
    reason = f"latest day with >= {DAILY_THRESHOLD} sales"
else:
    # fallback: use the day with the maximum count (still gives you a sensible anchor)
    end_date = daily_counts.idxmax()
    reason = f"no day with >= {DAILY_THRESHOLD}; using busiest day (count={int(daily_counts.max())})"

start_date = end_date - pd.DateOffset(years=1)

print("End date chosen:", end_date.date(), f"({reason})")
print("Start date:", start_date.date())
print("Sales on end date:", int(daily_counts.loc[end_date]))
print("Total sales in window:", int(raw[(raw['date'] >= start_date) & (raw['date'] <= end_date)].shape[0]))

# Filter to window
df_scot = raw[(raw["date"] >= start_date) & (raw["date"] <= end_date)].copy()

# Standardise schema like England
df_scot["property_type"] = "D"
df_scot["new_build"] = "N"
df_scot["record_status"] = "A"

key = df_scot["Link"].fillna(
    df_scot["postcode"] + "|" +
    df_scot["date"].dt.strftime("%Y-%m-%d") + "|" +
    df_scot["price"].astype("int64").astype("string")
)
df_scot["transaction_id"] = key.apply(lambda x: hashlib.md5(x.encode("utf-8")).hexdigest()).astype("string")

df_scot["month"] = df_scot["date"].dt.to_period("M").dt.to_timestamp()

df_scot = df_scot[[
    "transaction_id", "price", "date", "postcode",
    "property_type", "new_build", "record_status", "month"
]].copy()

df_scot.head()
# Out:
# End date chosen: 2024-08-30 (latest day with >= 50 sales)
# Start date: 2023-08-30
# Sales on end date: 243
# Total sales in window: 71636
#                        transaction_id     price       date  postcode  \
# 19   6334b05db756effd116c1ec8bbbccbb7   78000.0 2024-06-18  AB10 1AU
# 48   772b40190ba3633e2a2a037c235a4965   39999.0 2024-06-10  AB10 1BA
# 51   07e34a84debac46d5e4638f938c06f1b   32500.0 2023-12-01  AB10 1BA
# 196  c1fc2b97c55219b6ff2261b2a6ab0f78   85000.0 2024-05-31  AB10 1JE
# 242  dc00a9c713176148f4974041c09ea8f1  111000.0 2023-10-20  AB10 1JQ
#
#     property_type new_build record_status      month
# 19              D         N             A 2024-06-01
# 48              D         N             A 2024-06-01
# 51              D         N             A 2023-12-01
# 196             D         N             A 2024-05-01
# 242             D         N             A 2023-10-01

# %%
import os

DATASET_PATH = "/users/chris"

#for root, _, files in os.walk(DATASET_PATH):
    #for f in files:
        #print(os.path.join(root, f))

df_epc = pd.read_csv(
    "/users/chris/epc_prop_all.csv",
    low_memory=False
)

df_epc.head(), df_epc.shape
# Out:
# (   POSTCODE                         ADDRESS  TOTAL_FLOOR_AREA  \
#  0  NN10 9PW        96, St. Margarets Avenue              66.0
#  1   S42 7JJ  Barn 1 The Old Stables, Wigley             164.0
#  2  TA20 1FL              25, Wambrook Place              77.0
#  3  TN38 0QE   Top Floor Flat, 13 Clyde Road              49.0
#  4  WS14 9EY               11, Tamworth Road             120.0
#
#     NUMBER_HABITABLE_ROOMS  FLOOR_HEIGHT  BUILD_FORM INSPECTION_DATE
#  0                     4.0           NaN         NaN      2015-01-20
#  1                     6.0           NaN         NaN      2015-03-20
#  2                     NaN           NaN         NaN      2015-03-30
#  3                     2.0           NaN         NaN      2015-04-13
#  4                     6.0           NaN         NaN      2015-04-13  ,
#  (17177763, 7))

# %%
import pandas as pd

path = "/users/chris/pp-2025.txt"

# Full PPD schema (16 columns)
all_cols = [
    "transaction_id", "price", "date", "postcode",
    "property_type", "new_build", "tenure",
    "paon", "saon", "street", "locality", "town_city",
    "district", "county", "ppd_category", "record_status"
]

usecols = ["transaction_id", "price", "date", "postcode", "paon", "property_type", "new_build", "record_status"]

cutoff = (pd.Timestamp.today().normalize() - pd.DateOffset(years=5)).date()

chunks = []
for chunk in pd.read_csv(
    path,
    header=None,
    names=all_cols,
    usecols=usecols,
    dtype={
        "transaction_id": "string",
        "postcode": "string",
        "paon" : "string",
        "property_type": "string",
        "new_build": "string",
        "record_status": "string",
    },
    chunksize=500_000
):
    # Parse dates for this chunk
    chunk["date"] = pd.to_datetime(chunk["date"], errors="coerce")
    chunk = chunk[chunk["date"].notna()]

    # Keep only "A" records (usual rule)
    chunk = chunk[chunk["record_status"] == "A"]

    # Last 5 years
    chunk = chunk[chunk["date"].dt.date >= cutoff]

    chunks.append(chunk)

df = pd.concat(chunks, ignore_index=True)

# Month-start timestamp (for your downstream logic)
df["month"] = df["date"].dt.to_period("M").dt.to_timestamp()

print("Rows kept:", len(df))
print("Date range:", df["date"].min().date(), "->", df["date"].max().date())
# Out:
# Rows kept: 4667470
# Date range: 2021-02-19 -> 2025-12-24

# %%
cols = ["transaction_id", "price", "date", "postcode", "property_type",
        "new_build", "paon", "record_status", "month"]

df_e = df[cols].copy()

# Scotland: create paon as null, then align columns
df_s = df_scot.copy()
df_s["paon"] = pd.NA
df_s = df_s[cols].copy()

df_all = pd.concat([df_e, df_s], ignore_index=True)

print("England/Wales:", len(df_e))
print("Scotland:", len(df_s))
print("Combined:", len(df_all))
print("Combined date range:", df_all["date"].min(), "->", df_all["date"].max())
# Out:
# England/Wales: 4667470
# Scotland: 71636
# Combined: 4739106
# Combined date range: 2021-02-19 00:00:00 -> 2025-12-24 00:00:00

# %%
latest_month_start = df["month"].max()   # month-start timestamp
latest_month_end = (latest_month_start + pd.offsets.MonthEnd(0)).normalize()
days_in_latest_month = latest_month_end.day

# Shift ONLY Scotland
df_scot2 = df_scot.copy()

# Keep original day number but clamp to end-of-month (handles 29/30/31)
orig_day = df_scot2["date"].dt.day.clip(upper=days_in_latest_month)

df_scot2["date"] = pd.to_datetime({
    "year": latest_month_start.year,
    "month": latest_month_start.month,
    "day": orig_day
})

# Recompute month field
df_scot2["month"] = df_scot2["date"].dt.to_period("M").dt.to_timestamp()

# Rebuild combined df using shifted Scotland
df_all = pd.concat([df, df_scot2], ignore_index=True)

print("Latest month used:", latest_month_start.date())
print("Scotland shifted date range:", df_scot2["date"].min().date(), "->", df_scot2["date"].max().date())
# Out:
# Latest month used: 2025-12-01
# Scotland shifted date range: 2025-12-01 -> 2025-12-31

# %%
df = df_all

import re

def norm_postcode(s):
    if pd.isna(s): 
        return pd.NA
    return re.sub(r"\s+", "", str(s).upper().strip())

def norm_paon(s):
    if pd.isna(s):
        return pd.NA
    s = str(s).upper().strip()
    s = re.sub(r"\s+", "", s)   # remove spaces
    s = s.lstrip("0")           # 0007 -> 7 (optional, usually good)
    return s if s else pd.NA

def extract_paon_from_epc_address(addr):
    """
    Extract the *building number* from an EPC address string.
    Examples:
      "6 Apple Dene, Bramley" -> "6"
      "Flat 2, 6 Apple Dene, Bramley" -> "6"
      "Apartment 12, 101 High Street" -> "101"
      "12A High Street" -> "12A"
      "12-14 High Street" -> "12-14"
    """
    if pd.isna(addr):
        return pd.NA
    a = str(addr).strip().upper()

    # If starts with FLAT/APARTMENT/UNIT etc, try to grab the first number after a comma
    m = re.search(r"^(FLAT|APT|APARTMENT|UNIT|ROOM)\b.*?,\s*([0-9]+[A-Z]?(?:-[0-9]+[A-Z]?)?)\b", a)
    if m:
        return m.group(2)

    # Otherwise take the first leading number token
    m = re.match(r"^\s*([0-9]+[A-Z]?(?:-[0-9]+[A-Z]?)?)\b", a)
    if m:
        return m.group(1)

    return pd.NA

# %%
epc_addr_col = "address1" if "address1" in df_epc.columns else "ADDRESS"

df_epc2 = df_epc.copy()

df_epc2["pc_key"] = df_epc2["POSTCODE"].map(norm_postcode)
df_epc2["paon_raw"] = df_epc2[epc_addr_col].map(extract_paon_from_epc_address)
df_epc2["paon_key"] = df_epc2["paon_raw"].map(norm_paon)

# keep only what we need
keep = ["pc_key", "paon_key", "TOTAL_FLOOR_AREA", "NUMBER_HABITABLE_ROOMS", "INSPECTION_DATE"]
df_epc2 = df_epc2[keep].copy()

# make sure lodgement-date is sortable (if present)
if "INSPECTION_DATE" in df_epc2.columns:
    df_epc2["INSPECTION_DATE"] = pd.to_datetime(df_epc2["INSPECTION_DATE"], errors="coerce")

# DEDUPE: keep latest EPC per postcode+paon
df_epc_latest = (
    df_epc2.sort_values("INSPECTION_DATE")
           .drop_duplicates(subset=["pc_key", "paon_key"], keep="last")
)

# %%
df2 = df.copy()

df2["pc_key"] = df2["postcode"].map(norm_postcode)
df2["paon_key"] = df2["paon"].map(norm_paon)

# %%
df_joined = df2.merge(
    df_epc_latest[["pc_key", "paon_key", "TOTAL_FLOOR_AREA", "NUMBER_HABITABLE_ROOMS", "INSPECTION_DATE"]],
    on=["pc_key", "paon_key"],
    how="left"
)

df_joined.head()
# Out:
#                            transaction_id     price       date  postcode  \
# 0  {D707E535-5720-0AD9-E053-6B04A8C067CC}  260000.0 2021-08-06  SO45 2HT
# 1  {D707E535-5721-0AD9-E053-6B04A8C067CC}  375000.0 2021-09-01  SO23 7FR
# 2  {D707E535-5723-0AD9-E053-6B04A8C067CC}  132000.0 2021-06-28  SP11 6RL
# 3  {D707E535-5724-0AD9-E053-6B04A8C067CC}  295000.0 2021-09-10  SP11 6TU
# 4  {D707E535-5725-0AD9-E053-6B04A8C067CC}  360000.0 2021-08-27  SO51 0AX
#
#   property_type new_build paon record_status      month   pc_key paon_key  \
# 0             T         N   17             A 2021-08-01  SO452HT       17
# 1             S         N    1             A 2021-09-01  SO237FR        1
# 2             F         N    2             A 2021-06-01  SP116RL        2
# 3             T         N   21             A 2021-09-01  SP116TU       21
# 4             T         N  130             A 2021-08-01  SO510AX      130
#
#    TOTAL_FLOOR_AREA  NUMBER_HABITABLE_ROOMS INSPECTION_DATE
# 0               NaN                     NaN             NaT
# 1              73.0                     4.0      2025-04-17
# 2               NaN                     NaN             NaT
# 3              93.0                     4.0      2020-12-04
# 4               NaN                     NaN             NaT

# %%
print("Sales rows:", len(df2))
print("Joined rows:", len(df_joined))

match_rate = df_joined["TOTAL_FLOOR_AREA"].notna().mean()
print(f"Match rate (floor area not null): {match_rate:.1%}")

print("Distinct EPC matches:", df_joined.loc[df_joined["TOTAL_FLOOR_AREA"].notna(), ["pc_key","paon_key"]].drop_duplicates().shape[0])
# Out:
# Sales rows: 4739106
# Joined rows: 4739106
# Match rate (floor area not null): 73.5%
# Distinct EPC matches: 3158655

# %%
import numpy as np

# Work on a copy
df_filled = df_joined.copy()
# Define the grouping keys
GROUP_KEYS = ["postcode", "property_type", "new_build"]
# Calculate averages from rows with EPC data
postcode_avgs = (
    df_filled
    .loc[df_filled["TOTAL_FLOOR_AREA"].notna()]
    .groupby(GROUP_KEYS)
    .agg(
        avg_floor_area=("TOTAL_FLOOR_AREA", "mean"),
        avg_rooms=("NUMBER_HABITABLE_ROOMS", "mean"),
        count=("TOTAL_FLOOR_AREA", "size"),
    )
    .reset_index()
)
postcode_avgs.head()
# Out:
#    postcode property_type new_build  avg_floor_area  avg_rooms  count
# 0  AB43 9LS             D         N            42.0   2.000000      1
# 1   AL1 1AJ             D         N            93.0   5.000000      2
# 2   AL1 1AJ             S         N            89.0   5.250000      8
# 3   AL1 1AJ             T         N            74.0   4.666667      3
# 4   AL1 1AS             T         N            76.5   4.000000      2

# %%
df_filled = df_filled.merge(
    postcode_avgs,
    on=GROUP_KEYS,
    how="left"
)

df_filled["TOTAL_FLOOR_AREA_FILLED"] = np.where(
    df_filled["TOTAL_FLOOR_AREA"].notna(),
    df_filled["TOTAL_FLOOR_AREA"],
    df_filled["avg_floor_area"]
)

df_filled["NUMBER_HABITABLE_ROOMS_FILLED"] = np.where(
    df_filled["NUMBER_HABITABLE_ROOMS"].notna(),
    df_filled["NUMBER_HABITABLE_ROOMS"],
    df_filled["avg_rooms"]
)

df_filled["floor_area_source"] = np.where(
    df_filled["TOTAL_FLOOR_AREA"].notna(),
    "epc",
    np.where(df_filled["avg_floor_area"].notna(), "postcode_avg", "missing")
)

print("Original EPC coverage:", df_joined["TOTAL_FLOOR_AREA"].notna().mean())
print("After fill coverage:", df_filled["TOTAL_FLOOR_AREA_FILLED"].notna().mean())

print(
    df_filled["floor_area_source"]
    .value_counts(normalize=True)
    .rename(lambda x: f"{x}:")
)
# Out:
# Original EPC coverage: 0.7345855948358192
# After fill coverage: 0.8029001672467339
# epc:             0.734586
# missing:         0.197100
# postcode_avg:    0.068315
# Name: floor_area_source, dtype: float64

# %%
import pandas as pd
path_east_north = "/users/chris/ONSPD_Online_latest_Postcode_Centroids_.csv"

cols = [
    "x","y","PCDS"
]

df_en = pd.read_csv(
    path_east_north,    
    names=cols,    
    usecols=[0,1,4],
    skiprows=1,
    dtype={
        "x": "string",
        "y": "string",
        "PCDS": "string",
                
    }
)

df_en.head()
# Out:
#         x       y      PCDS
# 0  385386  801193  AB1  0AA
# 1  385177  801314  AB1  0AB
# 2  385053  801092  AB1  0AD
# 3  384600  799300  AB1  0AE
# 4  384460  800660  AB1  0AF

# %%
df_en["EAST1M"]  = pd.to_numeric(df_en["x"], errors="coerce")
df_en["NORTH1M"] = pd.to_numeric(df_en["y"], errors="coerce")

df_en = df_en.dropna(subset=["EAST1M","NORTH1M"]).copy()

# %%
GRID_SIZES = [1000, 5000, 10000, 25000]  # metres

for g in GRID_SIZES:
    df_en[f"gx_{g}"] = (df_en["EAST1M"] // g) * g
    df_en[f"gy_{g}"] = (df_en["NORTH1M"] // g) * g
    df_en[f"cell_{g}"] = (
        df_en[f"gx_{g}"].astype("Int64").astype(str) + "_" +
        df_en[f"gy_{g}"].astype("Int64").astype(str)
    )

# %%
def make_cells(df, g):
    cells = (df[[f"gx_{g}", f"gy_{g}"]]
             .drop_duplicates()
             .rename(columns={f"gx_{g}":"gx", f"gy_{g}":"gy"}))
    cells["grid_m"] = g
    cells["x0"] = cells["gx"]
    cells["y0"] = cells["gy"]
    cells["x1"] = cells["gx"] + g
    cells["y1"] = cells["gy"] + g
    return cells

cells_1km  = make_cells(df_en, 1000)
cells_5km  = make_cells(df_en, 5000)
cells_10km = make_cells(df_en, 10000)
cells_25km = make_cells(df_en, 25000)

print("1km:",  len(cells_1km))
print("5km:",  len(cells_5km))
print("10km:", len(cells_10km))
print("25km:", len(cells_25km))
# Out:
# 1km: 136132
# 5km: 9591
# 10km: 2809
# 25km: 555

# %%
df["pc_key"] = df["postcode"].astype("string").str.replace(" ", "", regex=False).str.upper()
df_en["pc_key"] = df_en["PCDS"].astype("string").str.replace(" ", "", regex=False).str.upper()

# %%
df_en["EAST1M"]  = pd.to_numeric(df_en["EAST1M"], errors="coerce")
df_en["NORTH1M"] = pd.to_numeric(df_en["NORTH1M"], errors="coerce")
df_en = df_en.dropna(subset=["EAST1M","NORTH1M"]).copy()

for g in [1000, 5000, 10000, 25000]:
    df_en[f"gx_{g}"] = ((df_en["EAST1M"] // g) * g).astype("int64")
    df_en[f"gy_{g}"] = ((df_en["NORTH1M"] // g) * g).astype("int64")
    df_en[f"cell_{g}"] = df_en[f"gx_{g}"].astype(str) + "_" + df_en[f"gy_{g}"].astype(str)

# %%
lookup_cols = [
    "pc_key",
    "EAST1M", "NORTH1M",
    "gx_1000", "gy_1000", "cell_1000",
    "gx_5000", "gy_5000", "cell_5000",
    "gx_10000", "gy_10000", "cell_10000",
    "gx_25000", "gy_25000", "cell_25000",
]

lookup = df_en[lookup_cols].drop_duplicates("pc_key")

to_drop = [c for c in lookup_cols if c in df_filled.columns and c != "pc_key"]
df_filled = df_filled.drop(columns=to_drop)

df_filled = df_filled.merge(lookup, on="pc_key", how="left")

# %%
df = df_filled

df["price_per_m2_raw"] = df["price"] / df["TOTAL_FLOOR_AREA_FILLED"]
df["price_per_room_raw"] = df["price"] / df["NUMBER_HABITABLE_ROOMS_FILLED"]

GROUP_KEYS = ["property_type", "new_build"]

ppm2_bounds = (
    df.groupby(GROUP_KEYS)["price_per_m2_raw"]
      .quantile([0.005, 0.995])
      .unstack()
      .rename(columns={0.005: "ppm2_lo", 0.995: "ppm2_hi"})
      .reset_index()
)

ppr_bounds = (
    df.groupby(GROUP_KEYS)["price_per_room_raw"]
      .quantile([0.005, 0.995])
      .unstack()
      .rename(columns={0.005: "ppr_lo", 0.995: "ppr_hi"})
      .reset_index()
)

df = (
    df.merge(ppm2_bounds, on=GROUP_KEYS, how="left")
      .merge(ppr_bounds, on=GROUP_KEYS, how="left")
)

df["price_per_m2"] = df["price_per_m2_raw"]
df.loc[
    (df["price_per_m2"] < df["ppm2_lo"]) |
    (df["price_per_m2"] > df["ppm2_hi"]),
    "price_per_m2"
] = np.nan

df["price_per_room"] = df["price_per_room_raw"]
df.loc[
    (df["price_per_room"] < df["ppr_lo"]) |
    (df["price_per_room"] > df["ppr_hi"]),
    "price_per_room"
] = np.nan

group_size = df.groupby(GROUP_KEYS)["price"].transform("size")
small = group_size < 50   # tweak if needed

df.loc[small, [
    "price_per_m2",
    "price_per_room"
]] = df.loc[small, [
    "price_per_m2_raw",
    "price_per_room_raw"
]]

print("£/m² clipped:", 
      (df["price_per_m2_raw"].notna() & df["price_per_m2"].isna()).mean())

print("£/room clipped:", 
      (df["price_per_room_raw"].notna() & df["price_per_room"].isna()).mean())
# Out:
# £/m² clipped: 0.008023665222934451
# £/room clipped: 0.00666560317494481

# %%
from pathlib import Path
import os, json, gzip
import pandas as pd
OUTPUT_DIR = Path(os.getenv("OUTPUT_DIR", "/users/chris"))
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

postcode_lookup = df_en[[
    "PCDS",
    "cell_1000", "cell_5000", "cell_10000", "cell_25000",
]].copy()

# Extract outcode (area) from full postcode and normalise
postcode_lookup["outcode"] = (
    postcode_lookup["PCDS"].astype("string").str.strip().str.split(" ", n=1).str[0].str.upper()
)
postcode_lookup = postcode_lookup.dropna(subset=["outcode"]).copy()

# Split each cell string (e.g. "385000_801000") into separate X/Y columns per grid size
for g in [1000, 5000, 10000, 25000]:
    cell_col = f"cell_{g}"
    x_col = f"cell_{g}_x"
    y_col = f"cell_{g}_y"
    # If the cell column exists, split on the underscore; keep as nullable Int64
    if cell_col in postcode_lookup.columns:
        parts = postcode_lookup[cell_col].astype("string").str.split("_", n=1, expand=True)
        postcode_lookup[x_col] = pd.to_numeric(parts[0], errors="coerce").astype("Int64")
        postcode_lookup[y_col] = pd.to_numeric(parts[1], errors="coerce").astype("Int64")
    else:
        postcode_lookup[x_col] = pd.Series([pd.NA] * len(postcode_lookup), dtype="Int64")
        postcode_lookup[y_col] = pd.Series([pd.NA] * len(postcode_lookup), dtype="Int64")

# Drop the original full postcode string column (`PCDS`) and the combined `cell_*` columns
drop_cells = [f"cell_{g}" for g in [1000, 5000, 10000, 25000]] + ["PCDS"]
postcode_lookup = postcode_lookup.drop(columns=[c for c in drop_cells if c in postcode_lookup.columns])

# Deduplicate by outcode + all grid X/Y coordinate pairs
dedupe_cols = ["outcode"] + [f"cell_{g}_x" for g in [1000, 5000, 10000, 25000]] + [f"cell_{g}_y" for g in [1000, 5000, 10000, 25000]]
postcode_lookup = postcode_lookup.drop_duplicates(subset=dedupe_cols)

# Save as parquet (compact, fast) and JSON (portable)
postcode_lookup_out_parquet = str(OUTPUT_DIR / "postcode_grid_outcode_lookup.parquet")
postcode_lookup_out_json = str(OUTPUT_DIR / "postcode_grid_outcode_lookup.json.gz")

postcode_lookup.to_parquet(postcode_lookup_out_parquet, index=False)

import json, gzip
with gzip.open(postcode_lookup_out_json, "wt", encoding="utf-8") as f:
    json.dump(postcode_lookup.where(pd.notnull(postcode_lookup), None).to_dict(orient="records"), f)

print("Wrote postcode lookup:", postcode_lookup_out_parquet, "rows:", len(postcode_lookup))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-cb52e5d2cea3> in <module>
#      46 import json, gzip
#      47 with gzip.open(postcode_lookup_out_json, "wt", encoding="utf-8") as f:
# ---> 48     json.dump(postcode_lookup.where(pd.notnull(postcode_lookup), None).to_dict(orient="records"), f)
#      49
#      50 print("Wrote postcode lookup:", postcode_lookup_out_parquet, "rows:", len(postcode_lookup))
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     427             yield _floatstr(o)
#     428         elif isinstance(o, (list, tuple)):
# --> 429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
#     431             yield from _iterencode_dict(o, _current_indent_level)
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type int64 is not JSON serializable

# %%
from pathlib import Path
import os, json, gzip
import pandas as pd
OUTPUT_DIR = Path(os.getenv("OUTPUT_DIR", "/users/chris"))
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

postcode_lookup = df_en[[
    "PCDS",
    "cell_1000", "cell_5000", "cell_10000", "cell_25000",
]].copy()

# Extract outcode (area) from full postcode and normalise
postcode_lookup["outcode"] = (
    postcode_lookup["PCDS"]
    .astype("string")
    .str.strip()
    .str.split(" ", n=1)
    .str[0]
    .str.upper()
)

postcode_lookup = postcode_lookup.dropna(subset=["outcode"]).copy()

# Split each cell string (e.g. "385000_801000") into separate X/Y columns per grid size
for g in [1000, 5000, 10000, 25000]:
    cell_col = f"cell_{g}"
    x_col = f"cell_{g}_x"
    y_col = f"cell_{g}_y"

    if cell_col in postcode_lookup.columns:
        parts = postcode_lookup[cell_col].astype("string").str.split("_", n=1, expand=True)
        postcode_lookup[x_col] = pd.to_numeric(parts[0], errors="coerce").astype("Int64")
        postcode_lookup[y_col] = pd.to_numeric(parts[1], errors="coerce").astype("Int64")
    else:
        postcode_lookup[x_col] = pd.Series([pd.NA] * len(postcode_lookup), dtype="Int64")
        postcode_lookup[y_col] = pd.Series([pd.NA] * len(postcode_lookup), dtype="Int64")

# Drop the original full postcode string column (`PCDS`) and the combined `cell_*` columns
drop_cells = [f"cell_{g}" for g in [1000, 5000, 10000, 25000]] + ["PCDS"]
postcode_lookup = postcode_lookup.drop(columns=[c for c in drop_cells if c in postcode_lookup.columns])

# Deduplicate by outcode + all grid X/Y coordinate pairs
dedupe_cols = (
    ["outcode"]
    + [f"cell_{g}_x" for g in [1000, 5000, 10000, 25000]]
    + [f"cell_{g}_y" for g in [1000, 5000, 10000, 25000]]
)
postcode_lookup = postcode_lookup.drop_duplicates(subset=dedupe_cols)

# Save as parquet (compact, fast) and JSON (portable)
postcode_lookup_out_parquet = str(OUTPUT_DIR / "postcode_grid_outcode_lookup.parquet")
postcode_lookup_out_json = str(OUTPUT_DIR / "postcode_grid_outcode_lookup.json.gz")

postcode_lookup.to_parquet(postcode_lookup_out_parquet, index=False)

# ---- JSON-safe export (handles numpy/pandas scalars like int64) ----
import numpy as np
import json, gzip

def json_safe(x):
    if x is None:
        return None
    # Handle NaN floats
    if isinstance(x, float) and np.isnan(x):
        return None
    # Convert numpy scalars to native Python types
    if isinstance(x, (np.integer,)):
        return int(x)
    if isinstance(x, (np.floating,)):
        return float(x)
    if isinstance(x, (np.bool_,)):
        return bool(x)
    return x

records = postcode_lookup.replace({pd.NA: None}).to_dict(orient="records")
records = [{k: json_safe(v) for k, v in r.items()} for r in records]

with gzip.open(postcode_lookup_out_json, "wt", encoding="utf-8") as f:
    json.dump(records, f, ensure_ascii=False)
# ---------------------------------------------------------------

print("Wrote postcode lookup:", postcode_lookup_out_parquet, "rows:", len(postcode_lookup))
print("Wrote postcode lookup:", postcode_lookup_out_json)
# Out:
# Wrote postcode lookup: \users\chris\postcode_grid_outcode_lookup.parquet rows: 164536
# Wrote postcode lookup: \users\chris\postcode_grid_outcode_lookup.json.gz

# %%
def build_outcode_index(df_lookup: pd.DataFrame, g: int) -> dict:
    x_col = f"cell_{g}_x"
    y_col = f"cell_{g}_y"
    if x_col not in df_lookup.columns or y_col not in df_lookup.columns:
        return {}

    d = df_lookup[["outcode", x_col, y_col]].dropna().copy()
    d[x_col] = d[x_col].astype("int64")
    d[y_col] = d[y_col].astype("int64")
    d["cell"] = d[x_col].astype(str) + "_" + d[y_col].astype(str)

    index = {}
    for cell, group in d.groupby("cell"):
        index[cell] = sorted(group["outcode"].astype(str).unique().tolist())
    return index

for g in [1000, 5000, 10000, 25000]:
    index = build_outcode_index(postcode_lookup, g)
    out_path = str(OUTPUT_DIR / f"postcode_outcode_index_{g//1000}km.json.gz")
    with gzip.open(out_path, "wt", encoding="utf-8") as f:
        json.dump(index, f)
    print("Wrote postcode outcode index:", out_path, "cells:", len(index))
# Out:
# Wrote postcode outcode index: \users\chris\postcode_outcode_index_1km.json.gz cells: 136132
# Wrote postcode outcode index: \users\chris\postcode_outcode_index_5km.json.gz cells: 9591
# Wrote postcode outcode index: \users\chris\postcode_outcode_index_10km.json.gz cells: 2809
# Wrote postcode outcode index: \users\chris\postcode_outcode_index_25km.json.gz cells: 555

# %%
df["month"] = df["date"].dt.to_period("M").dt.to_timestamp()

# optional but recommended for later
df["property_type"] = df["property_type"].astype("string")
df["new_build"] = df["new_build"].astype("string")

df["month"] = pd.to_datetime(df["month"]).dt.to_period("M").dt.to_timestamp()
latest_month = df["month"].max()
# Keep only last 10 years (inclusive, aligned to month)
cutoff_month = (latest_month - pd.DateOffset(years=10)).to_period("M").to_timestamp()
df = df[df["month"] >= cutoff_month].copy()

# %%
import pandas as pd

def _yearly_end_months(d_month_col: pd.Series, years_back: int):
    latest = d_month_col.max()
    end_months = [latest]
    cursor = latest - pd.DateOffset(years=1)
    min_month = d_month_col.min()
    while cursor >= min_month and len(end_months) < (years_back + 1):
        end_months.append(cursor)
        cursor -= pd.DateOffset(years=1)
    return end_months

def make_grid_annual_stack_levels(df, g, min_sales=3, years_back=10):
    """
    Returns ONE dataframe containing 4 levels:
      - TYPE+BUILD
      - TYPE+ALL
      - ALL+BUILD
      - ALL+ALL
    All use true medians (transaction-level) over trailing 12 months.
    """
    gx, gy = f"gx_{g}", f"gy_{g}"

    d = df.dropna(subset=[gx, gy]).copy()
    d["month"] = pd.to_datetime(d["month"]).dt.to_period("M").dt.to_timestamp()

    end_months = _yearly_end_months(d["month"], years_back=years_back)

    parts = []
    for end_month in end_months:
        start_month = (end_month - pd.DateOffset(months=11)).to_period("M").to_timestamp()
        w = d[(d["month"] >= start_month) & (d["month"] <= end_month)]

        # 1) TYPE + BUILD
        a = (w.groupby([gx, gy, "property_type", "new_build"], as_index=False)
               .agg(median_price_12m=("price", "median"),
                    sales_12m=("price", "size")))
        a["end_month"] = end_month
        parts.append(a)

        # 2) TYPE + ALL_BUILD
        b = (w.groupby([gx, gy, "property_type"], as_index=False)
               .agg(median_price_12m=("price", "median"),
                    sales_12m=("price", "size")))
        b["end_month"] = end_month
        b["new_build"] = "ALL"
        parts.append(b)

        # 3) ALL_TYPE + BUILD
        c = (w.groupby([gx, gy, "new_build"], as_index=False)
               .agg(median_price_12m=("price", "median"),
                    sales_12m=("price", "size")))
        c["end_month"] = end_month
        c["property_type"] = "ALL"
        parts.append(c)

        # 4) ALL_TYPE + ALL_BUILD
        d_all = (w.groupby([gx, gy], as_index=False)
                   .agg(median_price_12m=("price", "median"),
                        sales_12m=("price", "size")))
        d_all["end_month"] = end_month
        d_all["property_type"] = "ALL"
        d_all["new_build"] = "ALL"
        parts.append(d_all)

        print("done:", end_month.date(), "| window rows:", len(w))

    out = pd.concat(parts, ignore_index=True)

    # tidy
    out["end_month"] = pd.to_datetime(out["end_month"]).dt.to_period("M").dt.to_timestamp()
    out["property_type"] = out["property_type"].astype(str)
    out["new_build"] = out["new_build"].astype(str)

    if min_sales > 1:
        out = out[out["sales_12m"] >= min_sales].copy()

    return out

# %%
grid_25km_annual = make_grid_annual_stack_levels(
    df,
    g=25000,
    min_sales=3,
    years_back=10   # latest + last 10 yearly snapshots
)

grid_10km_annual = make_grid_annual_stack_levels(
    df,
    g=10000,
    min_sales=3,
    years_back=10   # latest + last 10 yearly snapshots
)

grid_5km_annual = make_grid_annual_stack_levels(
    df,
    g=5000,
    min_sales=3,
    years_back=10   # latest + last 10 yearly snapshots
)

grid_1km_annual = make_grid_annual_stack_levels(
    df,
    g=1000,
    min_sales=3,
    years_back=1   # latest + last 10 yearly snapshots
)
# Out:
# done: 2025-12-01 | window rows: 751450
# done: 2024-12-01 | window rows: 915337
# done: 2023-12-01 | window rows: 855687
# done: 2022-12-01 | window rows: 1071853
# done: 2021-12-01 | window rows: 1131700
# done: 2025-12-01 | window rows: 751450
# done: 2024-12-01 | window rows: 915337
# done: 2023-12-01 | window rows: 855687
# done: 2022-12-01 | window rows: 1071853
# done: 2021-12-01 | window rows: 1131700
# done: 2025-12-01 | window rows: 751450
# done: 2024-12-01 | window rows: 915337
# done: 2023-12-01 | window rows: 855687
# done: 2022-12-01 | window rows: 1071853
# done: 2021-12-01 | window rows: 1131700
# done: 2025-12-01 | window rows: 751450
# done: 2024-12-01 | window rows: 915337

# %%
grid_1km_annual.to_parquet("/users/chris/grid_1km_annual.parquet", index=False)
grid_5km_annual.to_parquet("/users/chris/grid_5km_annual.parquet", index=False)
grid_10km_annual.to_parquet("/users/chris/grid_10km_annual.parquet", index=False)
grid_25km_annual.to_parquet("/users/chris/grid_25km_annual.parquet", index=False)

# %%
from pathlib import Path
import os, json, gzip
import pandas as pd

OUTPUT_DIR = Path(os.getenv("OUTPUT_DIR", "/users/chris"))
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# quick runtime checks
for n in ("grid_1km_annual","grid_5km_annual","grid_10km_annual","grid_25km_annual"):
    if n not in globals():
        raise RuntimeError(f"{n} not found — run make_grid_annual_stack_levels first")

# %%
import pandas as pd, json, gzip

OUTPUT_DIR = Path(os.getenv("OUTPUT_DIR", "/users/chris"))
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

for grid_size, grid_annual in [
    (1000, grid_1km_annual),
    (5000, grid_5km_annual),
    (10000, grid_10km_annual),
    (25000, grid_25km_annual),
]:
    d = grid_annual.copy()
    g = grid_size
    d = d.rename(columns={
        f"gx_{g}": "gx",
        f"gy_{g}": "gy",
        "median_price_12m": "median",
        "sales_12m": "tx_count",
    })

    # Normalize end_month to ISO format (YYYY-MM-DD) required for API filtering
    d["end_month"] = pd.to_datetime(d["end_month"]).dt.strftime("%Y-%m-%d")

    keep = ["gx","gy","end_month","property_type","new_build","median","tx_count"]
    d = d[keep].dropna(subset=["gx","gy","median"]).copy()

    out_path = str(OUTPUT_DIR / f"grid_{g//1000}km_full.json.gz")
    with gzip.open(out_path, "wt", encoding="utf-8") as f:
        # JSON array (easy to parse/cached in worker)
        json.dump(d.to_dict(orient="records"), f)

    print("Wrote:", out_path, "rows:", len(d))

# Extract and store metadata: available date ranges for each dataset
grid_metadata = {}
for grid_size, grid_annual in [
    (1000, grid_1km_annual),
    (5000, grid_5km_annual),
    (10000, grid_10km_annual),
    (25000, grid_25km_annual),
]:
    grid_label = f"{grid_size // 1000}km"
    earliest = pd.to_datetime(grid_annual["end_month"].min()).strftime("%Y-%m-%d")
    latest = pd.to_datetime(grid_annual["end_month"].max()).strftime("%Y-%m-%d")
    grid_metadata[grid_label] = {
        "earliest": earliest,
        "latest": latest,
        "available_months": int(grid_annual["end_month"].nunique())
    }
# Save metadata JSON
metadata_path = "/users/chris/grid_metadata.json"
with open(metadata_path, "w") as f:
    json.dump(grid_metadata, f, indent=2)

print(f"\nGrid availability metadata:")
print(json.dumps(grid_metadata, indent=2))
print(f"Saved to {metadata_path}")
# Out:
# Wrote: \users\chris\grid_1km_full.json.gz rows: 398758
# Wrote: \users\chris\grid_5km_full.json.gz rows: 269523
# Wrote: \users\chris\grid_10km_full.json.gz rows: 107864
# Wrote: \users\chris\grid_25km_full.json.gz rows: 24880
#
# Grid availability metadata:
# {
#   "1km": {
#     "earliest": "2024-12-01",
#     "latest": "2025-12-01",
#     "available_months": 2
#   },
#   "5km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "available_months": 5
#   },
#   "10km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "available_months": 5
#   },
#   "25km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "available_months": 5
#   }
# }
# Saved to /users/chris/grid_metadata.json

# %%
import pandas as pd
import numpy as np
import plotly.express as px

def build_delta_df(grid_annual: pd.DataFrame, g: int,
                   property_type: str = "ALL", new_build: str = "ALL",
                   min_sales: int = 3,
                   end_month_latest=None,
                   end_month_oldest=None) -> pd.DataFrame:
    gx_col = f"gx_{g}"
    gy_col = f"gy_{g}"
    cell_col = f"cell_{g}"

    d = grid_annual.copy()
    d["end_month"] = pd.to_datetime(d["end_month"].astype(str)).dt.to_period("M").dt.to_timestamp()

    # segment filter (must be explicit to avoid dupes)
    d = d[(d["property_type"] == property_type) & (d["new_build"] == new_build)].copy()
    if d.empty:
        raise ValueError("No rows for that property_type/new_build. (Do you have ALL/ALL stacked?)")

    d = d.rename(columns={"median_price_12m": "median_price", "sales_12m": "sales"})
    d = d[d["sales"] >= min_sales].copy()

    # choose snapshot months
    if end_month_latest is None:
        end_month_latest = d["end_month"].max()
    else:
        end_month_latest = pd.to_datetime(str(end_month_latest)).to_period("M").to_timestamp()

    if end_month_oldest is None:
        end_month_oldest = d["end_month"].min()
    else:
        end_month_oldest = pd.to_datetime(str(end_month_oldest)).to_period("M").to_timestamp()

    latest = d[d["end_month"] == end_month_latest].copy()
    oldest = d[d["end_month"] == end_month_oldest].copy()

    if latest.empty or oldest.empty:
        raise ValueError("Chosen end_month_latest/end_month_oldest not found for that segment.")

    keep = [gx_col, gy_col, "median_price", "sales"]
    latest = latest[keep].rename(columns={"median_price": "price_latest", "sales": "sales_latest"})
    oldest = oldest[keep].rename(columns={"median_price": "price_oldest", "sales": "sales_oldest"})

    out = latest.merge(oldest, on=[gx_col, gy_col], how="inner")

    out["delta_gbp"] = out["price_latest"] - out["price_oldest"]
    out["delta_pct"] = np.where(out["price_oldest"] > 0,
                                (out["price_latest"] / out["price_oldest"] - 1.0) * 100.0,
                                np.nan)

    out[cell_col] = out[gx_col].astype("int64").astype(str) + "_" + out[gy_col].astype("int64").astype(str)
    out["end_month_latest"] = end_month_latest
    out["end_month_oldest"] = end_month_oldest
    out["property_type"] = property_type
    out["new_build"] = new_build

    return out

# %%
def plot_top_movers(delta_df: pd.DataFrame, n: int = 20):
    d = delta_df.dropna(subset=["delta_pct"]).copy()
    d = d.sort_values("delta_pct", ascending=False).head(n).copy()

    fig = px.bar(
        d,
        x="delta_pct",
        y=d.index.astype(str),
        hover_data={"delta_pct":":.1f","delta_gbp":":,.0f","price_oldest":":,.0f","price_latest":":,.0f"},
        title=f"Top {n} grid cells by Δ% (joined cells only)"
    )
    fig.update_layout(yaxis_title="row", xaxis_title="Δ%")
    fig.show(renderer="iframe")

# %%
def build_overall_deltas(grid_annual: pd.DataFrame, min_sales: int = 3) -> pd.DataFrame:
    """
    Compute deltas between earliest and latest available month across entire dataset.
    
    KAGGLE OPTIMIZATION:
    - Avoids storing all intermediate period deltas; only computes earliest→latest
    - Single merge operation (lower memory footprint than multi-period approach)
    - Filtered by min_sales to reduce output size
    - Returns only non-null deltas to save storage
    
    Args:
        grid_annual: Annual stacked grid data with columns [gx_*, gy_*, end_month, property_type, new_build, median, sales_12m]
        min_sales: Minimum transaction count to include
    
    Returns:
        DataFrame with columns [gx, gy, cell, property_type, new_build, 
        price_earliest, sales_earliest, end_month_earliest,
        price_latest, sales_latest, end_month_latest,
        delta_gbp, delta_pct, years_delta]
    """
    d = grid_annual.copy()
    print(f"DEBUG: build_overall_deltas input: {len(d)} rows, min_sales filter={min_sales}")
    d = d[d["sales_12m"] >= min_sales].copy()
    print(f"DEBUG: after min_sales filter: {len(d)} rows")
    
    if d.empty:
        return pd.DataFrame()
    
    # Find earliest and latest months available
    earliest_month = d["end_month"].min()
    latest_month = d["end_month"].max()
    
    print(f"DEBUG: earliest_month={earliest_month}, latest_month={latest_month}")
    
    if earliest_month == latest_month:
        print(f"Only one month available ({earliest_month}); skipping overall deltas")
        return pd.DataFrame()
    
    # Subset to earliest and latest only (memory efficient)
    earliest_data = d[d["end_month"] == earliest_month].copy()
    latest_data = d[d["end_month"] == latest_month].copy()
    
    # Determine grid size from column names (needed for debug output)
    grid_sizes = [g for col in earliest_data.columns if col.startswith("gx_") for g in [int(col.split("_")[1])]]
    if not grid_sizes:
        raise ValueError("No grid columns found (expected gx_*, gy_*)")
    g = grid_sizes[0]
    
    gx_col = f"gx_{g}"
    gy_col = f"gy_{g}"
    cell_col = f"cell_{g}"
    
    print(f"DEBUG earliest_data rows: {len(earliest_data)}, unique cells: {earliest_data[[gx_col, gy_col]].drop_duplicates().shape[0]}")
    print(f"DEBUG latest_data rows: {len(latest_data)}, unique cells: {latest_data[[gx_col, gy_col]].drop_duplicates().shape[0]}")
    
    # Group by cell, property_type, new_build at each time point
    earliest_agg = earliest_data.groupby([gx_col, gy_col, "property_type", "new_build"]).agg({
        "median_price_12m": "first",
        "sales_12m": "first"
    }).reset_index().rename(columns={"median_price_12m": "price_earliest", "sales_12m": "sales_earliest"})
    
    latest_agg = latest_data.groupby([gx_col, gy_col, "property_type", "new_build"]).agg({
        "median_price_12m": "first",
        "sales_12m": "first"
    }).reset_index().rename(columns={"median_price_12m": "price_latest", "sales_12m": "sales_latest"})
    
    print(f"DEBUG: earliest_agg={len(earliest_agg)} unique cell+segment combos")
    print(f"DEBUG: latest_agg={len(latest_agg)} unique cell+segment combos")
    
    # Inner join: only cells with data in both periods
    out = earliest_agg.merge(
        latest_agg,
        on=[gx_col, gy_col, "property_type", "new_build"],
        how="inner"
    )
    
    if out.empty:
        print(f"No cells with data in both {earliest_month} and {latest_month}")
        return pd.DataFrame()
    
    # DEBUG: Show coordinate distribution
    unique_cells = out[[gx_col, gy_col]].drop_duplicates()
    print(f"DEBUG: {len(unique_cells)} unique grid cells")
    print(f"DEBUG: {gx_col} range: {out[gx_col].min()} to {out[gx_col].max()}")
    print(f"DEBUG: {gy_col} range: {out[gy_col].min()} to {out[gy_col].max()}")
    if len(unique_cells) <= 10:
        print(f"DEBUG: Cells - {unique_cells.values.tolist()}")
    
    # Compute deltas
    out["delta_gbp"] = out["price_latest"] - out["price_earliest"]
    out["delta_pct"] = np.where(
        out["price_earliest"] > 0,
        (out["price_latest"] / out["price_earliest"] - 1.0) * 100.0,
        np.nan
    )
    
    # Add metadata
    out[cell_col] = out[gx_col].astype("int64").astype(str) + "_" + out[gy_col].astype("int64").astype(str)
    out["end_month_earliest"] = earliest_month
    out["end_month_latest"] = latest_month
    out["years_delta"] = (pd.to_datetime(latest_month).year - pd.to_datetime(earliest_month).year)
    # Also expose generic coordinate columns and a generic cell id for JSON consumers
    out["gx"] = out[gx_col].astype(float)
    out["gy"] = out[gy_col].astype(float)
    out["cell"] = out[cell_col].astype(str)
    
    # Select output columns (clean up grid-specific columns)
    # NOTE: sales_latest retained to contextualize large delta_pct values (sparse vs. robust moves)
    keep_cols = [
        gx_col, gy_col, "gx", "gy", cell_col, "cell", "property_type", "new_build",
        "price_earliest", "sales_earliest", "end_month_earliest",
        "price_latest", "sales_latest", "end_month_latest",
        "delta_gbp", "delta_pct", "years_delta"
    ]
    out = out[[c for c in keep_cols if c in out.columns]]
    
    # Filter to non-null deltas only (saves storage)
    out = out.dropna(subset=["delta_pct"])
    
    # Convert Timestamps to ISO format strings for JSON serialization
    out["end_month_earliest"] = pd.to_datetime(out["end_month_earliest"]).dt.strftime("%Y-%m-%d")
    out["end_month_latest"] = pd.to_datetime(out["end_month_latest"]).dt.strftime("%Y-%m-%d")
    
    return out.sort_values("delta_pct", ascending=False)

# %%
import json
import gzip
import numpy as np
import pandas as pd

# -----------------------------
# JSON-safe helpers
# -----------------------------
def json_safe(x):
    # pandas missing
    if x is pd.NA:
        return None
    # plain None
    if x is None:
        return None
    # NaN floats
    if isinstance(x, float) and np.isnan(x):
        return None
    # numpy scalars -> python scalars
    if isinstance(x, (np.integer,)):
        return int(x)
    if isinstance(x, (np.floating,)):
        return float(x)
    if isinstance(x, (np.bool_,)):
        return bool(x)
    # numpy arrays -> lists
    if isinstance(x, np.ndarray):
        return x.tolist()
    return x

def df_to_json_records(df: pd.DataFrame):
    # convert pandas NA to None, then ensure each value is json-safe
    records = df.replace({pd.NA: None}).to_dict(orient="records")
    return [{k: json_safe(v) for k, v in r.items()} for r in records]

def dict_to_json_safe(d):
    # recursively convert nested dict values to json-safe
    out = {}
    for k, v in d.items():
        if isinstance(v, dict):
            out[k] = dict_to_json_safe(v)
        else:
            out[k] = json_safe(v)
    return out

# -----------------------------
# Your loop
# -----------------------------
delta_metadata = {}

for grid_size, grid_annual in [
    (5000, grid_5km_annual),
    (10000, grid_10km_annual),
    (25000, grid_25km_annual),
]:
    grid_label = f"{grid_size // 1000}km"
    overall_deltas = build_overall_deltas(grid_annual, min_sales=5)

    if not overall_deltas.empty:
        cell_col = f"cell_{grid_size}"
        print(f"\n{'='*60}")
        print(f"Overall Deltas: {grid_label}")
        print(f"{'='*60}")
        print(f"Generated {len(overall_deltas)} cells with price movement")
        print(f"Time range: {overall_deltas['end_month_earliest'].iloc[0]} → {overall_deltas['end_month_latest'].iloc[0]}")
        print(f"Years: {overall_deltas['years_delta'].iloc[0]}")
        print(f"\nTop 10 gainers (%):")
        print(overall_deltas.nlargest(10, "delta_pct")[[cell_col, "property_type", "new_build", "sales_latest", "delta_pct", "delta_gbp"]])

        # Ensure grid coordinate columns are numeric but DO NOT force numpy int64
        gx_col = f"gx_{grid_size}"
        gy_col = f"gy_{grid_size}"
        for c in [gx_col, gy_col, "gx", "gy"]:
            if c in overall_deltas.columns:
                overall_deltas[c] = pd.to_numeric(overall_deltas[c], errors="coerce").round(0).astype("Int64")

        # Add centre lon/lat for convenience (EPSG:27700 -> EPSG:4326)
        try:
            x_cent = overall_deltas[gx_col].astype(float).to_numpy() + (grid_size / 2.0)
            y_cent = overall_deltas[gy_col].astype(float).to_numpy() + (grid_size / 2.0)
            lon_c, lat_c = TRANSFORMER.transform(x_cent, y_cent)

            # make sure these land as plain floats (not numpy arrays)
            overall_deltas["lon"] = np.asarray(lon_c, dtype=float)
            overall_deltas["lat"] = np.asarray(lat_c, dtype=float)
        except Exception:
            overall_deltas["lon"] = None
            overall_deltas["lat"] = None

        # Ensure timestamps / periods are strings for JSON
        if "end_month_earliest" in overall_deltas.columns:
            overall_deltas["end_month_earliest"] = overall_deltas["end_month_earliest"].astype(str)
        if "end_month_latest" in overall_deltas.columns:
            overall_deltas["end_month_latest"] = overall_deltas["end_month_latest"].astype(str)

        # Capture metadata for this grid
        earliest = overall_deltas["end_month_earliest"].iloc[0]
        latest = overall_deltas["end_month_latest"].iloc[0]
        delta_metadata[grid_label] = {
            "earliest": earliest,
            "latest": latest,
            "rows": int(len(overall_deltas)),
        }

        # Save to JSON gzip
        output_path = f"/users/chris/deltas_overall_{grid_label}.json.gz"
        with gzip.open(output_path, "wt", encoding="utf-8") as f:
            json.dump(df_to_json_records(overall_deltas), f, ensure_ascii=False)
        print(f"\nSaved to {output_path}")

    else:
        print(f"\nNo deltas generated for {grid_label}")

# Save delta metadata file
if delta_metadata:
    delta_metadata_path = "/users/chris/deltas_metadata.json"
    with open(delta_metadata_path, "w", encoding="utf-8") as f:
        json.dump(dict_to_json_safe(delta_metadata), f, indent=2, ensure_ascii=False)

    print(f"\n{'='*60}")
    print("Delta metadata:")
    print(json.dumps(dict_to_json_safe(delta_metadata), indent=2, ensure_ascii=False))
    print(f"Saved to {delta_metadata_path}")
# Out:
# DEBUG: build_overall_deltas input: 269523 rows, min_sales filter=5
# DEBUG: after min_sales filter: 230178 rows
# DEBUG: earliest_month=2021-12-01 00:00:00, latest_month=2025-12-01 00:00:00
# DEBUG earliest_data rows: 50335, unique cells: 5422
# DEBUG latest_data rows: 41474, unique cells: 5713
# DEBUG: earliest_agg=50335 unique cell+segment combos
# DEBUG: latest_agg=41474 unique cell+segment combos
# DEBUG: 4847 unique grid cells
# DEBUG: gx_5000 range: 90000.0 to 655000.0
# DEBUG: gy_5000 range: 10000.0 to 650000.0
#
# ============================================================
# Overall Deltas: 5km
# ============================================================
# Generated 36752 cells with price movement
# Time range: 2021-12-01 → 2025-12-01
# Years: 4
#
# Top 10 gainers (%):
#            cell_5000 property_type new_build  sales_latest     delta_pct  \
# 5501   325000_405000             O       ALL            10  79387.179487
# 5502   325000_405000             O         N            10  79387.179487
# 28531  515000_460000           ALL       ALL             6   3355.882353
# 22098  460000_185000             O         N             6   2375.000000
# 11363  380000_390000             O         N            28   1441.666667
# 11362  380000_390000             O       ALL            28   1441.666667
# 10360  370000_440000             O         N            10   1209.210526
# 10359  370000_440000             O       ALL            10   1209.210526
# 6881   340000_395000             O       ALL            10   1011.111111
# 6882   340000_395000             O         N            10   1011.111111
#
#        delta_gbp
# 5501   1548050.0
# 5502   1548050.0
# 28531   136920.0
# 22098   712500.0
# 11363   519000.0
# 11362   519000.0
# 10360  2297500.0
# 10359  2297500.0
# 6881   1820000.0
# 6882   1820000.0
#
# Saved to /users/chris/deltas_overall_5km.json.gz
# DEBUG: build_overall_deltas input: 107864 rows, min_sales filter=5
# DEBUG: after min_sales filter: 100350 rows
# DEBUG: earliest_month=2021-12-01 00:00:00, latest_month=2025-12-01 00:00:00
# DEBUG earliest_data rows: 20997, unique cells: 1639
# DEBUG latest_data rows: 19038, unique cells: 2057
# DEBUG: earliest_agg=20997 unique cell+segment combos
# DEBUG: latest_agg=19038 unique cell+segment combos
# DEBUG: 1594 unique grid cells
# DEBUG: gx_10000 range: 90000.0 to 650000.0
# DEBUG: gy_10000 range: 10000.0 to 650000.0
#
# ============================================================
# Overall Deltas: 10km
# ============================================================
# Generated 16887 cells with price movement
# Time range: 2021-12-01 → 2025-12-01
# Years: 4
#
# Top 10 gainers (%):
#           cell_10000 property_type new_build  sales_latest     delta_pct  \
# 3121   320000_400000             O         N            10  79387.179487
# 3120   320000_400000             O       ALL            10  79387.179487
# 14474   550000_90000             O       ALL             5  21990.909091
# 14475   550000_90000             O         N             5  21990.909091
# 15650  590000_110000             O       ALL             7   2632.142857
# 15651  590000_110000             O         N             7   2632.142857
# 9405   440000_230000             O       ALL             5   1027.774979
# 9406   440000_230000             O         N             5    954.035846
# 7440   410000_200000             O       ALL             5    824.271845
# 7441   410000_200000             O         N             5    824.271845
#
#        delta_gbp
# 3121   1548050.0
# 3120   1548050.0
# 14474   241900.0
# 14475   241900.0
# 15650   737000.0
# 15651   737000.0
# 9405   6243733.0
# 9406   6201233.0
# 7440   1061250.0
# 7441   1061250.0
#
# Saved to /users/chris/deltas_overall_10km.json.gz
# DEBUG: build_overall_deltas input: 24880 rows, min_sales filter=5
# DEBUG: after min_sales filter: 24173 rows
# DEBUG: earliest_month=2021-12-01 00:00:00, latest_month=2025-12-01 00:00:00
# DEBUG earliest_data rows: 4863, unique cells: 307
# DEBUG latest_data rows: 4994, unique cells: 464
# DEBUG: earliest_agg=4863 unique cell+segment combos
# DEBUG: latest_agg=4994 unique cell+segment combos
# DEBUG: 306 unique grid cells
# DEBUG: gx_25000 range: 75000.0 to 650000.0
# DEBUG: gy_25000 range: 0.0 to 650000.0
#
# ============================================================
# Overall Deltas: 25km
# ============================================================
# Generated 4340 cells with price movement
# Time range: 2021-12-01 → 2025-12-01
# Years: 4
#
# Top 10 gainers (%):
#          cell_25000 property_type new_build  sales_latest   delta_pct  \
# 2156  400000_425000             F         Y            13  358.647964
# 2329  425000_125000             T         Y             5  305.405405
# 2321  425000_125000             F         Y             6  184.182306
# 2291   425000_75000             F         Y             7  176.555556
# 1767  375000_325000             F         Y             8  174.468207
# 357   225000_375000             O         N            18  170.833333
# 356   225000_375000             O       ALL            18  170.833333
# 4333  650000_300000             O       ALL            54  153.378378
# 4334  650000_300000             O         N            54  153.378378
# 1661  375000_150000             T         Y             9  150.004310
#
#       delta_gbp
# 2156   276141.0
# 2329   904000.0
# 2321   343500.0
# 2291   397250.0
# 1767   122126.0
# 357    205000.0
# 356    205000.0
# 4333    56750.0
# 4334    56750.0
# 1661   435005.0
#
# Saved to /users/chris/deltas_overall_25km.json.gz
#
# ============================================================
# Delta metadata:
# {
#   "5km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "rows": 36752
#   },
#   "10km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "rows": 16887
#   },
#   "25km": {
#     "earliest": "2021-12-01",
#     "latest": "2025-12-01",
#     "rows": 4340
#   }
# }
# Saved to /users/chris/deltas_metadata.json

# %%
import pandas as pd
import numpy as np
import hashlib

# Load both
df_dl   = pd.read_json(r"C:\Users\chris\Downloads\deltas_overall_10km.json.gz", compression="gzip")
df_home = pd.read_json(r"C:\Users\chris\deltas_overall_10km.json.gz", compression="gzip")
key_cols = ["cell_10000", "property_type", "new_build", "end_month_earliest", "end_month_latest"]

# 1) Compare duplicate counts by key
c_dl = df_dl.groupby(key_cols, dropna=False).size().rename("count_downloads").reset_index()
c_hm = df_home.groupby(key_cols, dropna=False).size().rename("count_home").reset_index()

dup_cmp = c_dl.merge(c_hm, on=key_cols, how="outer").fillna(0)
dup_cmp["count_downloads"] = dup_cmp["count_downloads"].astype(int)
dup_cmp["count_home"] = dup_cmp["count_home"].astype(int)
dup_cmp["diff"] = dup_cmp["count_downloads"] - dup_cmp["count_home"]

print("Total rows Downloads:", len(df_dl))
print("Total rows Home:", len(df_home))
print("Extra rows in Downloads:", len(df_dl) - len(df_home))

print("\nKeys with different duplicate counts:", (dup_cmp["diff"] != 0).sum())
display(dup_cmp.loc[dup_cmp["diff"] != 0].sort_values("diff", ascending=False).head(50))

# 2) How many duplicates exist overall
print("\nDuplicate rows (full-row duplicates) in Downloads:", df_dl.duplicated().sum())
print("Duplicate rows (full-row duplicates) in Home:", df_home.duplicated().sum())

# 3) Dedup both and confirm equality on keys + values
dl_dedup = df_dl.drop_duplicates(subset=key_cols).sort_values(key_cols).reset_index(drop=True)
hm_dedup = df_home.drop_duplicates(subset=key_cols).sort_values(key_cols).reset_index(drop=True)

print("\nAfter dedupe")
print("Downloads rows:", len(dl_dedup))
print("Home rows:", len(hm_dedup))

# If these match, the data is identical ignoring duplicates
same = dl_dedup.equals(hm_dedup)
print("Deduped dataframes identical:", same)
# Out:
# Total rows Downloads: 16904
# Total rows Home: 16887
# Extra rows in Downloads: 17
#
# Keys with different duplicate counts: 17
#          cell_10000 property_type new_build end_month_earliest  \
# 181     17000060000             S         N         2021-12-01
# 6610   390000200000             T         N         2021-12-01
# 12079  490000170000             T         Y         2021-12-01
# 9075   430000350000             F         N         2021-12-01
# 9074   430000350000             F       ALL         2021-12-01
# 7507   400000570000             S         N         2021-12-01
# 7506   400000570000             S       ALL         2021-12-01
# 7118   400000200000           ALL         Y         2021-12-01
# 6609   390000200000             T       ALL         2021-12-01
# 668     27000080000             F         N         2021-12-01
# 6600   390000190000             T         N         2021-12-01
# 6599   390000190000             T       ALL         2021-12-01
# 3592   320000560000             D         N         2021-12-01
# 3591   320000560000             D       ALL         2021-12-01
# 1926   250000260000             T         N         2021-12-01
# 1925   250000260000             T       ALL         2021-12-01
# 13317  510000440000             D         Y         2021-12-01
#
#       end_month_latest  count_downloads  count_home  diff
# 181         2025-12-01                1           0     1
# 6610        2025-12-01                1           0     1
# 12079       2025-12-01                1           0     1
# 9075        2025-12-01                1           0     1
# 9074        2025-12-01                1           0     1
# 7507        2025-12-01                1           0     1
# 7506        2025-12-01                1           0     1
# 7118        2025-12-01                1           0     1
# 6609        2025-12-01                1           0     1
# 668         2025-12-01                1           0     1
# 6600        2025-12-01                1           0     1
# 6599        2025-12-01                1           0     1
# 3592        2025-12-01                1           0     1
# 3591        2025-12-01                1           0     1
# 1926        2025-12-01                1           0     1
# 1925        2025-12-01                1           0     1
# 13317       2025-12-01                1           0     1
# Duplicate rows (full-row duplicates) in Downloads: 0
# Duplicate rows (full-row duplicates) in Home: 0
#
# After dedupe
# Downloads rows: 16904
# Home rows: 16887
# Deduped dataframes identical: False
